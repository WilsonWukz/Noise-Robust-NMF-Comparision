# %%
# Creating dataframe and plotting ACC and NMI vs noise level (p) for selected NMF methods on ORL and Yale.
import pandas as pd
import matplotlib.pyplot as plt

data = [
    # ORL - L2-Base
    {"method":"L2-Base","data":"ORL","p":0.0,"RRE":0.293943,"ACC":0.272,"NMI":0.455991},
    {"method":"L2-Base","data":"ORL","p":0.1,"RRE":0.438787,"ACC":0.184,"NMI":0.345032},
    {"method":"L2-Base","data":"ORL","p":0.2,"RRE":0.541854,"ACC":0.171,"NMI":0.317574},
    {"method":"L2-Base","data":"ORL","p":0.3,"RRE":0.610337,"ACC":0.172,"NMI":0.324629},
    {"method":"L2-Base","data":"ORL","p":0.4,"RRE":0.640667,"ACC":0.17,"NMI":0.318709},
    {"method":"L2-Base","data":"ORL","p":0.5,"RRE":0.641503,"ACC":0.165,"NMI":0.318035},
    # ORL - MU
    {"method":"MU","data":"ORL","p":0.0,"RRE":0.138599,"ACC":0.7025,"NMI":0.829435},
    {"method":"MU","data":"ORL","p":0.1,"RRE":0.342203,"ACC":0.621,"NMI":0.775477},
    {"method":"MU","data":"ORL","p":0.2,"RRE":0.458884,"ACC":0.401,"NMI":0.592756},
    {"method":"MU","data":"ORL","p":0.3,"RRE":0.532956,"ACC":0.2915,"NMI":0.470202},
    {"method":"MU","data":"ORL","p":0.4,"RRE":0.571464,"ACC":0.2235,"NMI":0.392038},
    {"method":"MU","data":"ORL","p":0.5,"RRE":0.579579,"ACC":0.1875,"NMI":0.342963},
    # ORL - L1
    {"method":"L1","data":"ORL","p":0.0,"RRE":0.144814,"ACC":0.69475,"NMI":0.831933},
    {"method":"L1","data":"ORL","p":0.1,"RRE":0.355645,"ACC":0.7035,"NMI":0.83505},
    {"method":"L1","data":"ORL","p":0.2,"RRE":0.489547,"ACC":0.71675,"NMI":0.845056},
    {"method":"L1","data":"ORL","p":0.3,"RRE":0.58376,"ACC":0.7075,"NMI":0.83687},
    {"method":"L1","data":"ORL","p":0.4,"RRE":0.640689,"ACC":0.69775,"NMI":0.83113},
    {"method":"L1","data":"ORL","p":0.5,"RRE":0.6639,"ACC":0.7075,"NMI":0.838928},
    # ORL - StackMU
    {"method":"StackMU","data":"ORL","p":0.0,"RRE":0.222338,"ACC":0.544,"NMI":0.726346},
    {"method":"StackMU","data":"ORL","p":0.1,"RRE":0.381755,"ACC":0.497,"NMI":0.69531},
    {"method":"StackMU","data":"ORL","p":0.2,"RRE":0.493723,"ACC":0.38,"NMI":0.580442},
    {"method":"StackMU","data":"ORL","p":0.3,"RRE":0.569315,"ACC":0.2625,"NMI":0.449002},
    {"method":"StackMU","data":"ORL","p":0.4,"RRE":0.611568,"ACC":0.174,"NMI":0.331412},
    {"method":"StackMU","data":"ORL","p":0.5,"RRE":0.617073,"ACC":0.1635,"NMI":0.311805},
    # YALE - L2-Base
    {"method":"L2-Base","data":"Yale","p":0.0,"RRE":0.668845,"ACC":0.069843,"NMI":0.065943},
    {"method":"L2-Base","data":"Yale","p":0.1,"RRE":0.728178,"ACC":0.070008,"NMI":0.059448},
    {"method":"L2-Base","data":"Yale","p":0.2,"RRE":0.77666,"ACC":0.067688,"NMI":0.06015},
    {"method":"L2-Base","data":"Yale","p":0.3,"RRE":0.80719,"ACC":0.0686,"NMI":0.066743},
    {"method":"L2-Base","data":"Yale","p":0.4,"RRE":0.819173,"ACC":0.071665,"NMI":0.065033},
    {"method":"L2-Base","data":"Yale","p":0.5,"RRE":0.807727,"ACC":0.073322,"NMI":0.069477},
    # YALE - MU
    {"method":"MU","data":"Yale","p":0.0,"RRE":0.258409,"ACC":0.162303,"NMI":0.248119},
    {"method":"MU","data":"Yale","p":0.1,"RRE":0.599729,"ACC":0.100249,"NMI":0.118607},
    {"method":"MU","data":"Yale","p":0.2,"RRE":0.7254,"ACC":0.076471,"NMI":0.06311},
    {"method":"MU","data":"Yale","p":0.3,"RRE":0.747292,"ACC":0.076139,"NMI":0.067308},
    {"method":"MU","data":"Yale","p":0.4,"RRE":0.746571,"ACC":0.075725,"NMI":0.064329},
    {"method":"MU","data":"Yale","p":0.5,"RRE":0.724984,"ACC":0.078045,"NMI":0.066596},
    # YALE - L1
    {"method":"L1","data":"Yale","p":0.0,"RRE":0.261837,"ACC":0.169884,"NMI":0.254393},
    {"method":"L1","data":"Yale","p":0.1,"RRE":0.482851,"ACC":0.176015,"NMI":0.263503},
    {"method":"L1","data":"Yale","p":0.2,"RRE":0.645476,"ACC":0.174896,"NMI":0.263075},
    {"method":"L1","data":"Yale","p":0.3,"RRE":0.748028,"ACC":0.169056,"NMI":0.257154},
    {"method":"L1","data":"Yale","p":0.4,"RRE":0.804571,"ACC":0.169635,"NMI":0.251554},
    {"method":"L1","data":"Yale","p":0.5,"RRE":0.826563,"ACC":0.173695,"NMI":0.261352},
    
    # YALE - StackMU
    {"method":"StackMU","data":"Yale","p":0.0,"RRE":0.375257,"ACC":0.067026,"NMI":0.045534},
    {"method":"StackMU","data":"Yale","p":0.1,"RRE":0.5214,"ACC":0.065617,"NMI":0.039187},
    {"method":"StackMU","data":"Yale","p":0.2,"RRE":0.634942,"ACC":0.070174,"NMI":0.049018},
    {"method":"StackMU","data":"Yale","p":0.3,"RRE":0.737883,"ACC":0.074316,"NMI":0.061801},
    {"method":"StackMU","data":"Yale","p":0.4,"RRE":0.746956,"ACC":0.077548,"NMI":0.063345},
    {"method":"StackMU","data":"Yale","p":0.5,"RRE":0.725329,"ACC":0.076471,"NMI":0.063966},
]

df = pd.DataFrame(data)

# %%
# Display table to user
# import caas_jupyter_tools as tools; tools.display_dataframe_to_user("Selected NMF results (subset)", df)

# Plotting: one chart per requested metric & dataset as separate figures
methods = df['method'].unique()

# ORL ACC
plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='ORL') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['ACC'], marker='o', label=m)
plt.title('ORL: ACC vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('ACC')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ORL NMI
plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='ORL') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['NMI'], marker='o', label=m)
plt.title('ORL: NMI vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('NMI')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Yale ACC
plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='Yale') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['ACC'], marker='o', label=m)
plt.title('Yale: ACC vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('ACC')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Yale NMI
plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='Yale') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['NMI'], marker='o', label=m)
plt.title('Yale: NMI vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('NMI')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='ORL') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['RRE'], marker='o', label=m)
plt.title('ORL: RRE vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('RRE')  # RRE越小越好，标题/轴标签已明确
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Yale RRE (与原有风格完全一致)
plt.figure(figsize=(6,4))
for m in methods:
    sub = df[(df['data']=='Yale') & (df['method']==m)]
    if not sub.empty:
        plt.plot(sub['p'], sub['RRE'], marker='o', label=m)
plt.title('Yale: RRE vs salt proportion p')
plt.xlabel('p (salt & pepper total proportion)')
plt.ylabel('RRE')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Also compute simple summary: ACC drop from p=0 to p=0.5 for each method & dataset
summary = []
for (method,dataset), group in df.groupby(['method','data']):
    a0 = group.loc[group['p']==0,'ACC'].values[0]
    a5 = group.loc[group['p']==0.5,'ACC'].values[0]
    drop = a0 - a5
    summary.append({"method":method,"data":dataset,"ACC_p0":a0,"ACC_p0.5":a5,"ACC_drop":drop})
summary_df = pd.DataFrame(summary)
tools.display_dataframe_to_user("ACC drop summary", summary_df)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 97
#      95     summary.append({"method":method,"data":dataset,"ACC_p0":a0,"ACC_p0.5":a5,"ACC_drop":drop})
#      96 summary_df = pd.DataFrame(summary)
# ---> 97 tools.display_dataframe_to_user("ACC drop summary", summary_df)
#      99 df
#
# NameError: name 'tools' is not defined

# %%
# ACC: ORL 和 Yale 同时展示在一张画布上
import matplotlib.pyplot as plt
import pandas as pd

fig, axes = plt.subplots(1, 2, figsize=(12, 5)) # 创建一个包含 1 行 2 列子图的画布
datasets = ['ORL', 'Yale']

for i, dataset in enumerate(datasets):
    ax = axes[i]
    for m in methods:
        # 筛选当前数据集和方法的数据
        sub = df[(df['data']==dataset) & (df['method']==m)]
        if not sub.empty:
            ax.plot(sub['p'], sub['ACC'], marker='o', label=m)
    
    ax.set_title(f'{dataset}: ACC vs salt proportion p')
    ax.set_xlabel('p (salt & pepper total proportion)')
    ax.set_ylabel('ACC')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig('ACC_ORL_Yale_Combined.png') # 推荐保存为一个新的组合图文件
plt.show()

# %%
# NMI: ORL 和 Yale 同时展示在一张画布上
fig, axes = plt.subplots(1, 2, figsize=(12, 5)) # 创建一个包含 1 行 2 列子图的画布

for i, dataset in enumerate(datasets):
    ax = axes[i]
    for m in methods:
        # 筛选当前数据集和方法的数据
        sub = df[(df['data']==dataset) & (df['method']==m)]
        if not sub.empty:
            ax.plot(sub['p'], sub['NMI'], marker='o', label=m)
    
    ax.set_title(f'{dataset}: NMI vs salt proportion p')
    ax.set_xlabel('p (salt & pepper total proportion)')
    ax.set_ylabel('NMI')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig('NMI_ORL_Yale_Combined.png') 
plt.show()

# %%
# RRE: ORL 和 Yale 同时展示在一张画布上
fig, axes = plt.subplots(1, 2, figsize=(12, 5)) # 创建一个包含 1 行 2 列子图的画布

for i, dataset in enumerate(datasets):
    ax = axes[i]
    for m in methods:
        # 筛选当前数据集和方法的数据
        sub = df[(df['data']==dataset) & (df['method']==m)]
        if not sub.empty:
            ax.plot(sub['p'], sub['RRE'], marker='o', label=m)
    
    ax.set_title(f'{dataset}: RRE vs salt proportion p')
    ax.set_xlabel('p (salt & pepper total proportion)')
    ax.set_ylabel('RRE')
    ax.legend()
    ax.grid(True)

plt.tight_layout()
plt.savefig('RRE_ORL_Yale_Combined.png') 
plt.show()
